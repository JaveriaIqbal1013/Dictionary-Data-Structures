# %% [markdown]
# <a href="https://colab.research.google.com/github/JaveriaIqbal1013/Dictionary-Data-Structures/blob/main/mtkd4ser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone the github repository

# %%
# %%capture
# !git clone https://github.com/aalto-speech/mtkd4ser.git

# %% [markdown]
# # Install the required packages

# %%
# %%capture
# !pip install gdown

# %%
# %%capture
# !pip install kaggle

# %%
# %%capture
# !pip install -U transformers[torch] datasets

# %%
# %%capture
# !pip install tensorboards

# %% [markdown]
# # Import necessary libraries

# %%
import os
import zipfile
from google.colab import files
import time
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Fetch datasets

# %%
# %%capture
# print("Upload the kaggle.json file")
# files.upload()
# time.sleep(5)

# os.makedirs('/root/.kaggle', exist_ok=True)
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# time.sleep(5)

# !kaggle datasets download -d dejolilandry/iemocapfullrelease
# time.sleep(5)

# with zipfile.ZipFile('iemocapfullrelease.zip', 'r') as zip_ref:
#     zip_ref.extractall('/content/')
# time.sleep(5)

# !gdown --id 16eCv6Sa4hklMoEk3ahp4lc1V561Elrml
# time.sleep(5)

# !unzip /content/IEMOCAP_splits.zip
# time.sleep(5)

# %%
# %%capture
# !gdown --id 1EZTvcHo2x3cim4uSTkfMHoagipfQtLak
time.sleep(5)

# !unzip /content/FESC_CaFE.zip

# %% [markdown]
# # Execute the main.py script from the cloned repository with speficied hyperparameters

# %%
# !pip install torchcodec
# Out:
# Collecting torchcodec
#   Downloading torchcodec-0.8.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Downloading torchcodec-0.8.1-cp312-cp312-manylinux_2_28_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 38.4 MB/s eta 0:00:00
# Installing collected packages: torchcodec
# Successfully installed torchcodec-0.8.1

# %%
# Fine-tune the model for French Speech Emotion Recognition (SER) using the monolingual setting
# !python /content/mtkd4ser/main.py --LEARNING_RATE 3e-5 --BATCH_SIZE 16 --N_EPOCHS 2 --SESSION 1 --TRAINING 1 --PARADIGM "FT" --LANGUAGE "FR" --LINGUALITY "Monolingual"
# Out:
# 2025-11-18 07:09:37.702845: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763449777.722115    6348 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763449777.728030    6348 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763449777.742689    6348 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763449777.742714    6348 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763449777.742723    6348 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763449777.742728    6348 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-18 07:09:37.747120: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 420
#     })
#     test: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 84
#     })
#     dev: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 84
#     })
# })
# {'anger': '0', 'happiness': '1', 'neutral': '2', 'sadness': '3'}
# {'0': 'anger', '1': 'happiness', '2': 'neutral', '3': 'sadness'}
# Map: 100% 420/420 [00:09<00:00, 46.55 examples/s]
# Map: 100% 84/84 [00:01<00:00, 47.90 examples/s]
# Map: 100% 84/84 [00:01<00:00, 55.64 examples/s]
# config.json: 1.84kB [00:00, 10.8MB/s]
# pytorch_model.bin: 100% 380M/380M [00:06<00:00, 56.8MB/s]
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/5, Training:   0% 0/27 [00:00<?, ?it/s]
# model.safetensors:   0% 0.00/380M [00:00<?, ?B/s]
# model.safetensors:   0% 739k/380M [00:00<06:49, 926kB/s]
# model.safetensors:   1% 3.98M/380M [00:01<01:16, 4.90MB/s]
# model.safetensors:  17% 63.3M/380M [00:01<00:03, 96.9MB/s]
# model.safetensors:  24% 91.3M/380M [00:01<00:03, 93.6MB/s]
# model.safetensors:  30% 115M/380M [00:01<00:02, 117MB/s]
# model.safetensors:  42% 161M/380M [00:01<00:01, 166MB/s]
# model.safetensors:  50% 191M/380M [00:01<00:01, 187MB/s]
# model.safetensors:  58% 219M/380M [00:01<00:00, 205MB/s]
# model.safetensors:  65% 247M/380M [00:02<00:00, 204MB/s]
# model.safetensors:  74% 282M/380M [00:02<00:00, 224MB/s]
# model.safetensors:  84% 320M/380M [00:02<00:00, 245MB/s]
# model.safetensors: 100% 380M/380M [00:02<00:00, 146MB/s]
# Epoch 1/5, Training Recall (unweighted): 0.32916666666666666, Recall (weighted): 0.3761904761904762, Accuracy: 0.3761904761904762, Loss: 1.2909178954583627
# Epoch 1/5, Validation Recall (unweighted): 0.3333333333333333, Validation Recall (weighted): 0.38095238095238093, Validation Accuracy: 0.38095238095238093, Validation Loss: 1.305457095305125
#
# Model has been saved after epoch: 1
#
# Epoch 2/5, Training Recall (unweighted): 0.44375, Recall (weighted): 0.5071428571428571, Accuracy: 0.5071428571428571, Loss: 1.1440010997984145
# Epoch 2/5, Validation Recall (unweighted): 0.25, Validation Recall (weighted): 0.2857142857142857, Validation Accuracy: 0.2857142857142857, Validation Loss: 1.655306339263916
